# %% [markdown]
# ## Contents
#     0.1 Importing Libraries
#     0.2 Importing 2015 Data
#         0.3 Initial Inspection of 2015 Data
#         0.4 Identify Missing Values
#         0.5 Remove Duplicates
#         0.6 Exporting Cleaned Data
#     1.1 Importing 2016 Data
#         1.2 Initial Inspection of 2016 Data
#         1.3 Identify Missing Values
#         1.4 Remove Duplicates
#         1.5 Exporting Cleaned Data
#     2.1 Importing 2017 Data
#         2.2 Initial Inspection of 2017 Data
#         2.3 Updating Column Names
#         2.4 Identify Missing Values
#         2.5 Remove Duplicates
#         2.6 Exporting Cleaned Data
#     3.1 Importing 2018 Data
#         3.2 Initial Inspection of 2018 Data
#         3.3 Updating Column Names
#         3.4 Identify Missing Values
#         3.5 Remove Duplicates
#         3.6 Exporting Cleaned Data
#     4.1 Importing 2019 Data
#         4.2 Initial Inspection of 2019 Data
#         4.3 Updating Column Names
#         4.4 Identify Missing Values
#         4.5 Remove Duplicates
#         4.6 Exporting Cleaned Data

# %% [markdown]
# #### 0.1 Importing Libraries

# %%
# importing libraries

import pandas as pd
import numpy as np
import os

# %%
# establishing a path

path = '/Users/vickyczada/Library/CloudStorage/OneDrive-Personal/Documents/Career Foundry/Data Immersion/Achievement 6/World Happiness Report'

# %%
path
# Out:
# '/Users/vickyczada/Library/CloudStorage/OneDrive-Personal/Documents/Career Foundry/Data Immersion/Achievement 6/World Happiness Report'

# %% [markdown]
# #### 0.2 Importing 2015 Data

# %%
# importing dataframe

df_2015 = pd.read_csv(os.path.join(path,'02 Data', 'Original Data', '2015.csv'), index_col = False)

# %%
# checking dataframe

df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df_2015.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %% [markdown]
# Unclear what the column Standard Error is for and if it needs to be removed

# %% [markdown]
# #### 0.3 Initial Inspection of 2015 Data

# %%
# summary statistics

print(df_2015.info)
# Out:
# <bound method DataFrame.info of          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# ...

# %%
df_2015.shape
# Out:
# (158, 12)

# %%
df_2015.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df_2015.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# All dtypes look correct

# %% [markdown]
# Column Names: All look good and reflect what is in the column no changes to be made

# %% [markdown]
# #### 0.4 Identify Missing Values

# %%
# Count missing values per column

print(df_2015.isnull().sum())
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# No missing values indentified

# %% [markdown]
# #### 0.5 Remove Duplicates

# %%
# find duplicates

df_dups = df_2015[df_2015.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Standard Error, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
df_dups.shape
# Out:
# (0, 12)

# %% [markdown]
# No duplicates found

# %% [markdown]
# #### 0.6 Exporting Cleaned Data

# %%
df_2015.to_pickle(os.path.join(path, '02 Data','Prepared Data', '2015_World_Happiness_Report.pkl'))

# %% [markdown]
# #### 1.1 Importing 2016 Data

# %%
# importing dataframe

df_2016 = pd.read_csv(os.path.join(path,'02 Data', 'Original Data', '2016.csv'), index_col = False)

# %%
# checking dataframe
df_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
df_2016.tail()
# Out:
#          Country                           Region  Happiness Rank  \
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 152            3.484                      3.404                      3.564
# 153            3.360                      3.288                      3.432
# 154            3.303                      3.192                      3.414
# 155            3.069                      2.936                      3.202
# 156            2.905                      2.732                      3.078
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# #### 1.2 Initial Inspection of 2016 Data

# %%
# summary statistics

print(df_2016.info)
# Out:
# <bound method DataFrame.info of          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# ...

# %%
df_2016.shape
# Out:
# (157, 13)

# %%
df_2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# 2 of the column names are different in 2015 there is the column 'Standard Error' however there is not in 2016 instead it has 'Lower Confidence Interval' and 'Upper Confidence Interval', need to research but may need to remove to merge the data

# %%
df_2016.describe()
# Out:
#        Happiness Rank  Happiness Score  Lower Confidence Interval  \
# count      157.000000       157.000000                 157.000000
# mean        78.980892         5.382185                   5.282395
# std         45.466030         1.141674                   1.148043
# min          1.000000         2.905000                   2.732000
# 25%         40.000000         4.404000                   4.327000
# 50%         79.000000         5.314000                   5.237000
# 75%        118.000000         6.269000                   6.154000
# max        157.000000         7.526000                   7.460000
#
#        Upper Confidence Interval  Economy (GDP per Capita)      Family  \
# count                 157.000000                157.000000  157.000000
# mean                    5.481975                  0.953880    0.793621
# std                     1.136493                  0.412595    0.266706
# min                     3.078000                  0.000000    0.000000
# ...

# %%
df_2016.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Lower Confidence Interval        float64
# Upper Confidence Interval        float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# Dtypes look the same as 2015 and all look good

# %% [markdown]
# #### 1.3 Identify Missing Values

# %%
# Count missing values per column

print(df_2016.isnull().sum())
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# No missing values

# %% [markdown]
# #### 1.4 Remove Duplicates

# %%
# find duplicates

df_dups_2016 = df_2016[df_2016.duplicated()]

# %%
df_dups_2016
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Lower Confidence Interval, Upper Confidence Interval, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
df_dups_2016.shape
# Out:
# (0, 13)

# %% [markdown]
# No duplicates found

# %% [markdown]
# #### 1.5 Exporting Cleaned Data

# %%
df_2016.to_pickle(os.path.join(path, '02 Data','Prepared Data', '2016_World_Happiness_Report.pkl'))

# %% [markdown]
# #### 2.1 Importing 2017 Data

# %%
# importing dataframe

df_2017 = pd.read_csv(os.path.join(path,'02 Data', 'Original Data', '2017.csv'), index_col = False)

# %%
# checking dataframe

df_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
df_2017.tail()
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 150     3.398970                  0.368746  0.945707
# 151     3.260331                  0.777153  0.396103
# 152     3.236570                  0.511136  1.041990
# 153     2.735310                  0.091623  0.629794
# 154     2.521116                  0.000000  0.000000
#
#      Health..Life.Expectancy.   Freedom  Generosity  \
# 150                  0.326425  0.581844    0.252756
# 151                  0.500533  0.081539    0.493664
# ...

# %% [markdown]
# #### 2.2 Initial Inspection of 2017 Data

# %%
# summary statistics

print(df_2017.info)
# Out:
# <bound method DataFrame.info of                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
df_2017.shape
# Out:
# (155, 12)

# %%
df_2017.describe()
# Out:
#        Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# count      155.000000       155.000000    155.000000   155.000000
# mean        78.000000         5.354019      5.452326     5.255713
# std         44.888751         1.131230      1.118542     1.145030
# min          1.000000         2.693000      2.864884     2.521116
# 25%         39.500000         4.505500      4.608172     4.374955
# 50%         78.000000         5.279000      5.370032     5.193152
# 75%        116.500000         6.101500      6.194600     6.006527
# max        155.000000         7.537000      7.622030     7.479556
#
#        Economy..GDP.per.Capita.      Family  Health..Life.Expectancy.  \
# count                155.000000  155.000000                155.000000
# mean                   0.984718    1.188898                  0.551341
# std                    0.420793    0.287263                  0.237073
# min                    0.000000    0.000000                  0.000000
# ...

# %%
df_2017.dtypes
# Out:
# Country                           object
# Happiness.Rank                     int64
# Happiness.Score                  float64
# Whisker.high                     float64
# Whisker.low                      float64
# Economy..GDP.per.Capita.         float64
# Family                           float64
# Health..Life.Expectancy.         float64
# Freedom                          float64
# Generosity                       float64
# Trust..Government.Corruption.    float64
# Dystopia.Residual                float64
# dtype: object

# %%
df_2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %% [markdown]
# There is no regional data for this year, look at the last 2 years and decide if to add it in or remove the column from the other years.

# %% [markdown]
# #### 2.3 Update Column Names

# %%
df_2017.rename(columns={
    'Happiness.Rank': 'Happiness Rank',
    'Happiness.Score': 'Happiness Score',
    'Whisker.high': 'Whisker High',
    'Whisker.low': 'Whisker Low',
    'Economy..GDP.per.Capita.': 'Economy (GDP per Capita)',
    'Family': 'Family',
    'Health..Life.Expectancy.': 'Health (Life Expectancy)',
    'Freedom': 'Freedom',
    'Trust..Government.Corruption.': 'Trust (Government Corruption)',
    'Generosity': 'Generosity',
    'Dystopia.Residual': 'Dystopia Residual'
}, inplace=True)

# %% [markdown]
# For now, I will retain the "Whisker High" and "Whisker Low" columns in the dataset. Since these columns are similar to the "Upper Confidence Interval" and "Lower Confidence Interval" columns but exhibit inconsistencies across the data period, I prefer to hold off on merging them. In future analysis, once I evaluate the overall data quality and consistency, I can decide whether to exclude or integrate these columns. If I determine that the data can be merged smoothly, I will remove the "Whisker" columns to avoid redundancy.

# %%
# check the change in name

df_2017.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Whisker High  Whisker Low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust (Government Corruption)  Dystopia Residual
# ...

# %% [markdown]
# #### 2.4 Identify Missing Values

# %%
# Count missing values per column

print(df_2017.isnull().sum())
# Out:
# Country                          0
# Happiness Rank                   0
# Happiness Score                  0
# Whisker High                     0
# Whisker Low                      0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Generosity                       0
# Trust (Government Corruption)    0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# No missing values identified

# %% [markdown]
# #### 2.5 Remove Duplicates

# %%
# find duplicates

df_dups_2017 = df_2017[df_2017.duplicated()]

# %%
df_dups_2017
# Out:
# Empty DataFrame
# Columns: [Country, Happiness Rank, Happiness Score, Whisker High, Whisker Low, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Generosity, Trust (Government Corruption), Dystopia Residual]
# Index: []

# %%
df_dups_2017.shape
# Out:
# (0, 12)

# %% [markdown]
# #### 2.6 Exporting Cleaned Data

# %%
df_2017.to_pickle(os.path.join(path, '02 Data','Prepared Data', '2017_World_Happiness_Report.pkl'))

# %% [markdown]
# #### 3.1 Importing 2018 Data

# %%
# importing dataframe

df_2018 = pd.read_csv(os.path.join(path,'02 Data', 'Original Data', '2018.csv'), index_col = False)

# %%
# checking dataframe

df_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
df_2018.tail()
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 151           1.073                    0.343                         0.244
# 152           0.991                    0.381                         0.481
# 153           0.608                    0.177                         0.112
# 154           0.000                    0.010                         0.305
# 155           0.627                    0.145                         0.065
#
#      Generosity  Perceptions of corruption
# 151       0.083                      0.064
# ...

# %% [markdown]
# #### 3.2 Initial Inspection of 2018 Data

# %%
# summary statistics

print(df_2018.info)
# Out:
# <bound method DataFrame.info of      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
df_2018.shape
# Out:
# (156, 9)

# %%
df_2018.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.375917        0.891449        1.213237
# std       45.177428    1.119506        0.391921        0.302372
# min        1.000000    2.905000        0.000000        0.000000
# 25%       39.750000    4.453750        0.616250        1.066750
# 50%       78.500000    5.378000        0.949500        1.255000
# 75%      117.250000    6.168500        1.197750        1.463000
# max      156.000000    7.632000        2.096000        1.644000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.597346                      0.454506    0.181006
# std                   0.247579                      0.162424    0.098471
# min                   0.000000                      0.000000    0.000000
# ...

# %%
df_2018.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %% [markdown]
# #### 3.3 Update Column Names

# %%
df_2018.rename(columns={
    'Overall rank': 'Happiness Rank',
    'Score': 'Happiness Score',
    'GDP per capita': 'Economy (GDP per Capita)',
    'Social support': 'Social Support',
    'Healthy life expectancy': 'Health (Life Expectancy)',
    'Freedom to make life choices': 'Freedom',
    'Generosity': 'Generosity',
    'Perceptions of corruption': 'Trust (Government Corruption)',
}, inplace=True)

# %%
# check they have changed 

df_2018.head()
# Out:
#    Happiness Rank Country or region  Happiness Score  \
# 0               1           Finland            7.632
# 1               2            Norway            7.594
# 2               3           Denmark            7.555
# 3               4           Iceland            7.495
# 4               5       Switzerland            7.487
#
#    Economy (GDP per Capita)  Social Support  Health (Life Expectancy)  \
# 0                     1.305           1.592                     0.874
# 1                     1.456           1.582                     0.861
# 2                     1.351           1.590                     0.868
# 3                     1.343           1.644                     0.914
# 4                     1.420           1.549                     0.927
#
#    Freedom  Generosity  Trust (Government Corruption)
# 0    0.681       0.202                          0.393
# 1    0.686       0.286                          0.340
# 2    0.683       0.284                          0.408
# ...

# %%
df_2018['Country or region'].value_counts()
# Out:
# Country or region
# Finland      1
# Ghana        1
# Nepal        1
# Venezuela    1
# Gabon        1
#             ..
# Latvia       1
# Japan        1
# Mauritius    1
# Jamaica      1
# Burundi      1
# Name: count, Length: 156, dtype: int64

# %%
# allow to see all rows 

pd.set_option('display.max_rows', None)

# %%
df_2018['Country or region'].value_counts()
# Out:
# Country or region
# Finland                     1
# Ghana                       1
# Nepal                       1
# Venezuela                   1
# Gabon                       1
# Palestinian Territories     1
# South Africa                1
# Iran                        1
# Ivory Coast                 1
# Senegal                     1
# Cameroon                    1
# Laos                        1
# Tunisia                     1
# Albania                     1
# Sierra Leone                1
# Congo (Brazzaville)         1
# Bangladesh                  1
# Sri Lanka                   1
# Bulgaria                    1
# Somalia                     1
# Norway                      1
# Tajikistan                  1
# Montenegro                  1
# Croatia                     1
# Dominican Republic          1
# Algeria                     1
# Morocco                     1
# China                       1
# Azerbaijan                  1
# Macedonia                   1
# ...

# %%
# compare against 2016 country column

df_2016['Country'].value_counts()
# Out:
# Country
# Denmark                    1
# Albania                    1
# Laos                       1
# Nigeria                    1
# Honduras                   1
# Iran                       1
# Zambia                     1
# Nepal                      1
# Palestinian Territories    1
# Bangladesh                 1
# Tajikistan                 1
# Sierra Leone               1
# Iraq                       1
# Namibia                    1
# Cameroon                   1
# Ethiopia                   1
# South Africa               1
# Sri Lanka                  1
# Mongolia                   1
# Greece                     1
# Jordan                     1
# Dominican Republic         1
# Philippines                1
# China                      1
# Bhutan                     1
# Kyrgyzstan                 1
# Serbia                     1
# Bosnia and Herzegovina     1
# Montenegro                 1
# Morocco                    1
# Tunisia                    1
# ...

# %% [markdown]
# There are no regions in the column therefore I will change the name of the column to Country like the other years instead of country or region

# %%
# change the column name 

df_2018.rename(columns={
    'Country or region': 'Country'
}, inplace=True)

# %%
# check

df_2018.head()
# Out:
#    Happiness Rank      Country  Happiness Score  Economy (GDP per Capita)  \
# 0               1      Finland            7.632                     1.305
# 1               2       Norway            7.594                     1.456
# 2               3      Denmark            7.555                     1.351
# 3               4      Iceland            7.495                     1.343
# 4               5  Switzerland            7.487                     1.420
#
#    Social Support  Health (Life Expectancy)  Freedom  Generosity  \
# 0           1.592                     0.874    0.681       0.202
# 1           1.582                     0.861    0.686       0.286
# 2           1.590                     0.868    0.683       0.284
# 3           1.644                     0.914    0.677       0.353
# 4           1.549                     0.927    0.660       0.256
#
#    Trust (Government Corruption)
# 0                          0.393
# 1                          0.340
# ...

# %% [markdown]
# #### 3.4 Identify Missing Values

# %%
# Count missing values per column

print(df_2018.isnull().sum())
# Out:
# Happiness Rank                   0
# Country                          0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Social Support                   0
# Health (Life Expectancy)         0
# Freedom                          0
# Generosity                       0
# Trust (Government Corruption)    1
# dtype: int64

# %% [markdown]
# Only one missing value, will not remove as it will not affect the overall outcome of the data

# %% [markdown]
# #### 3.5 Remove Duplicates

# %%
# find duplicates

df_dups_2018 = df_2018[df_2018.duplicated()]

# %%
df_dups_2018
# Out:
# Empty DataFrame
# Columns: [Happiness Rank, Country, Happiness Score, Economy (GDP per Capita), Social Support, Health (Life Expectancy), Freedom, Generosity, Trust (Government Corruption)]
# Index: []

# %%
df_dups_2018.shape
# Out:
# (0, 9)

# %% [markdown]
# #### 3.6 Exporting Cleaned Data

# %%
df_2018.to_pickle(os.path.join(path, '02 Data','Prepared Data', '2018_World_Happiness_Report.pkl'))

# %% [markdown]
# #### 4.1 Importing 2019 Data

# %%
# importing dataframe

df_2019 = pd.read_csv(os.path.join(path,'02 Data', 'Original Data', '2019.csv'), index_col = False)

# %%
# checking dataframe

df_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
df_2019.tail()
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption
# 151       0.217                      0.411
# ...

# %% [markdown]
# #### 4.2 Initial Inspection of 2019 Data

# %%
# summary statistics

print(df_2019.info)
# Out:
# <bound method DataFrame.info of      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# 5               6               Switzerland  7.480           1.452
# 6               7                    Sweden  7.343           1.387
# 7               8               New Zealand  7.307           1.303
# 8               9                    Canada  7.278           1.365
# 9              10                   Austria  7.246           1.376
# 10             11                 Australia  7.228           1.372
# 11             12                Costa Rica  7.167           1.034
# ...

# %%
df_2019.shape
# Out:
# (156, 9)

# %%
df_2019.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %%
df_2019.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %% [markdown]
# #### 3.3 Updating Column Names

# %%
df_2019.rename(columns={
    'Overall rank': 'Happiness Rank',
    'Score': 'Happiness Score',
    'GDP per capita': 'Economy (GDP per Capita)',
    'Social support': 'Social Support',
    'Healthy life expectancy': 'Health (Life Expectancy)',
    'Freedom to make life choices': 'Freedom',
    'Generosity': 'Generosity',
    'Perceptions of corruption': 'Trust (Government Corruption)'
}, inplace=True)

# %%
# check the update

df_2019.head()
# Out:
#    Happiness Rank Country or region  Happiness Score  \
# 0               1           Finland            7.769
# 1               2           Denmark            7.600
# 2               3            Norway            7.554
# 3               4           Iceland            7.494
# 4               5       Netherlands            7.488
#
#    Economy (GDP per Capita)  Social Support  Health (Life Expectancy)  \
# 0                     1.340           1.587                     0.986
# 1                     1.383           1.573                     0.996
# 2                     1.488           1.582                     1.028
# 3                     1.380           1.624                     1.026
# 4                     1.396           1.522                     0.999
#
#    Freedom  Generosity  Trust (Government Corruption)
# 0    0.596       0.153                          0.393
# 1    0.592       0.252                          0.410
# 2    0.603       0.271                          0.341
# ...

# %%
df_2019['Country or region'].value_counts()
# Out:
# Country or region
# Finland                     1
# Venezuela                   1
# Jordan                      1
# Benin                       1
# Congo (Brazzaville)         1
# Gabon                       1
# Laos                        1
# South Africa                1
# Albania                     1
# Cambodia                    1
# Ivory Coast                 1
# Palestinian Territories     1
# Senegal                     1
# Somalia                     1
# Namibia                     1
# Niger                       1
# Burkina Faso                1
# Armenia                     1
# Nepal                       1
# Ghana                       1
# Denmark                     1
# Algeria                     1
# Belarus                     1
# Greece                      1
# Mongolia                    1
# North Macedonia             1
# Nigeria                     1
# Kyrgyzstan                  1
# Turkmenistan                1
# Morocco                     1
# ...

# %%
# change the column name 

df_2019.rename(columns={
    'Country or region': 'Country'
}, inplace=True)

# %%
# check the change 

df_2019.head()
# Out:
#    Happiness Rank      Country  Happiness Score  Economy (GDP per Capita)  \
# 0               1      Finland            7.769                     1.340
# 1               2      Denmark            7.600                     1.383
# 2               3       Norway            7.554                     1.488
# 3               4      Iceland            7.494                     1.380
# 4               5  Netherlands            7.488                     1.396
#
#    Social Support  Health (Life Expectancy)  Freedom  Generosity  \
# 0           1.587                     0.986    0.596       0.153
# 1           1.573                     0.996    0.592       0.252
# 2           1.582                     1.028    0.603       0.271
# 3           1.624                     1.026    0.591       0.354
# 4           1.522                     0.999    0.557       0.322
#
#    Trust (Government Corruption)
# 0                          0.393
# 1                          0.410
# ...

# %% [markdown]
# #### 3.4 Identify Missing Values

# %%
# Count missing values per column

print(df_2019.isnull().sum())
# Out:
# Happiness Rank                   0
# Country                          0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Social Support                   0
# Health (Life Expectancy)         0
# Freedom                          0
# Generosity                       0
# Trust (Government Corruption)    0
# dtype: int64

# %% [markdown]
# No missing values found

# %% [markdown]
# #### 3.5 Remove Duplicates

# %%
# find duplicates

df_dups_2019 = df_2019[df_2019.duplicated()]

# %%
df_dups_2019
# Out:
# Empty DataFrame
# Columns: [Happiness Rank, Country, Happiness Score, Economy (GDP per Capita), Social Support, Health (Life Expectancy), Freedom, Generosity, Trust (Government Corruption)]
# Index: []

# %%
df_dups_2019.shape
# Out:
# (0, 9)

# %% [markdown]
# #### 3.6 Exporting Cleaned Data

# %%
df_2019.to_pickle(os.path.join(path, '02 Data','Prepared Data', '2019_World_Happiness_Report.pkl'))
