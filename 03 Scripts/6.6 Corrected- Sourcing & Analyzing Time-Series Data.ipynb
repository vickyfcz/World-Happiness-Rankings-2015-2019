# %% [markdown]
# #### 6.6 Sourcing & Analyzing Time-Series Data

# %% [markdown]
# 1. Importing your libraries and data
# 2. Subsetting, wrangling, and cleaning time-series data
# 3. Time series analysis: decomposition
# 4. Testing for stationarity
# 5. Stationarizing the Federal Reserve Economic Data

# %% [markdown]
# #### 1.Importing libraries and data

# %%
# !pip install quandl
# Out:
# Requirement already satisfied: quandl in /opt/anaconda3/lib/python3.12/site-packages (3.7.0)
# Requirement already satisfied: pandas>=0.14 in /opt/anaconda3/lib/python3.12/site-packages (from quandl) (2.2.3)
# Requirement already satisfied: numpy>=1.8 in /opt/anaconda3/lib/python3.12/site-packages (from quandl) (1.26.4)
# Requirement already satisfied: requests>=2.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from quandl) (2.32.3)
# Requirement already satisfied: inflection>=0.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from quandl) (0.5.1)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/lib/python3.12/site-packages (from quandl) (2.9.0.post0)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.12/site-packages (from quandl) (1.16.0)
# Requirement already satisfied: more-itertools in /opt/anaconda3/lib/python3.12/site-packages (from quandl) (10.3.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=0.14->quandl) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=0.14->quandl) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.7.0->quandl) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.7.0->quandl) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.7.0->quandl) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.7.0->quandl) (2025.6.15)

# %%
import quandl
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import statsmodels.api as sm 
import os
import warnings 

warnings.filterwarnings("ignore") 

plt.style.use('fivethirtyeight')

# %%
# Configure API key 

quandl.ApiConfig.api_key = '5vQ1DzAsgwuuR7vE-u-v'

# %%
import nasdaqdatalink

# %%
# still did not work, took the suggestion from the AI

# %%
# trying another way with different data to see if that works

# %%
nasdaqdatalink.ApiConfig.api_key = '5vQ1DzAsgwuuR7vE-u-v'
nasdaqdatalink.get_table('QDL/ODA')
# Out:
#             indicator       date  value
# None
# 0         ZWE_TX_RPCH 2028-12-31    NaN
# 1         ZWE_TX_RPCH 2027-12-31    NaN
# 2         ZWE_TX_RPCH 2026-12-31    NaN
# 3         ZWE_TX_RPCH 2025-12-31    NaN
# 4         ZWE_TX_RPCH 2024-12-31    NaN
# ...               ...        ...    ...
# 9995           WSM_LE 1980-12-31    NaN
# 9996  WSM_GGXWDN_NGDP 2028-12-31    NaN
# 9997  WSM_GGXWDN_NGDP 2027-12-31    NaN
# 9998  WSM_GGXWDN_NGDP 2026-12-31    NaN
# 9999  WSM_GGXWDN_NGDP 2025-12-31    NaN
#
# [10000 rows x 3 columns]

# %%
# it worked! trying with the dataframe I want to use

# %%
data_WB = nasdaqdatalink.get_table('WB/DATA')

# %%
data_WB.head()
# Out:
#            series_id country_code country_name  year  value
# None
# 0     VC.PKP.TOTL.UN          XKX       Kosovo  2017  357.0
# 1     VC.PKP.TOTL.UN          XKX       Kosovo  2016  462.0
# 2     VC.PKP.TOTL.UN          XKX       Kosovo  2015  640.0
# 3     VC.PKP.TOTL.UN          XKX       Kosovo  2014  736.0
# 4     VC.PKP.TOTL.UN          XKX       Kosovo  2013  756.0

# %%
data_WB.tail()
# Out:
#         series_id country_code                               country_name  \
# None
# 9995  VC.IDP.TOCV          TUR                                    Turkiye
# 9996  VC.IDP.TOCV          TUR                                    Turkiye
# 9997  VC.IDP.TOCV          TUR                                    Turkiye
# 9998  VC.IDP.TOCV          TUN                                    Tunisia
# 9999  VC.IDP.TOCV          TSS  Sub-Saharan Africa (IDA & IBRD countries)
#
#       year       value
# None
# 9995  2011   1000000.0
# 9996  2010   1000000.0
# 9997  2009   1000000.0
# 9998  2019         4.0
# 9999  2023  32420020.0

# %%
data.shape
# Out:
# (9109067, 5)

# %%
counts =data_WB['country_name'].value_counts()

print(counts)
# Out:
# country_name
# Japan                                            96
# Netherlands                                      96
# Costa Rica                                       96
# Colombia                                         96
# Switzerland                                      96
#                                                  ..
# East Asia & Pacific (all income levels)           1
# Ethiopia                                          1
# Latin America & Caribbean (all income levels)     1
# Europe & Central Asia (all income levels)         1
# Arab League states                                1
# Name: count, Length: 256, dtype: int64

# %%
pd.options.display.max_rows= None

# %%
print(counts)
# Out:
# country_name
# Japan                                                   96
# Netherlands                                             96
# Costa Rica                                              96
# Colombia                                                96
# Switzerland                                             96
# Canada                                                  96
# Germany                                                 96
# Denmark                                                 96
# Norway                                                  96
# Croatia                                                 96
# Romania                                                 96
# Bulgaria                                                96
# Russian Federation                                      96
# Austria                                                 96
# Australia                                               96
# Mexico                                                  96
# United States                                           96
# Hungary                                                 96
# World                                                   94
# Italy                                                   94
# Ireland                                                 94
# Armenia                                                 94
# Puerto Rico                                             93
# Brazil                                                  93
# Greece                                                  93
# Poland                                                  92
# Finland                                                 91
# Moldova                                                 91
# Albania                                                 90
# Lithuania                                               90
# Mauritius                                               90
# Estonia                                                 88
# Portugal                                                86
# Ecuador                                                 86
# St. Lucia                                               86
# Barbados                                                86
# Panama                                                  84
# Bahamas, The                                            84
# Cuba                                                    84
# Israel                                                  82
# Venezuela, RB                                           81
# Czechia                                                 81
# New Zealand                                             80
# Ukraine                                                 80
# Sweden                                                  78
# India                                                   78
# Slovak Republic                                         75
# Spain                                                   74
# Hong Kong SAR, China                                    70
# Cyprus                                                  69
# Cayman Islands                                          69
# Belgium                                                 69
# Slovenia                                                68
# Serbia                                                  66
# Jamaica                                                 66
# Thailand                                                66
# Guatemala                                               65
# Malta                                                   65
# Qatar                                                   65
# North Macedonia                                         64
# Singapore                                               64
# Guyana                                                  64
# Kosovo                                                  63
# Turkiye                                                 63
# United Kingdom                                          63
# El Salvador                                             62
# Bermuda                                                 62
# Iceland                                                 62
# Uruguay                                                 62
# Antigua and Barbuda                                     61
# Honduras                                                61
# Macao SAR, China                                        61
# Dominican Republic                                      60
# Kyrgyz Republic                                         59
# Grenada                                                 56
# Bosnia and Herzegovina                                  56
# Belarus                                                 56
# Nicaragua                                               55
# Azerbaijan                                              55
# St. Vincent and the Grenadines                          55
# Luxembourg                                              54
# Trinidad and Tobago                                     54
# St. Kitts and Nevis                                     54
# Korea, Rep.                                             54
# Paraguay                                                52
# Chile                                                   52
# Liechtenstein                                           52
# Morocco                                                 52
# Uganda                                                  52
# Aruba                                                   51
# San Marino                                              51
# South Africa                                            51
# Belize                                                  50
# Dominica                                                50
# Latvia                                                  50
# Myanmar                                                 50
# Montenegro                                              50
# Georgia                                                 50
# Jordan                                                  49
# Mongolia                                                49
# Virgin Islands (U.S.)                                   48
# Bahrain                                                 48
# Philippines                                             47
# Uzbekistan                                              47
# Tonga                                                   47
# France                                                  46
# Kazakhstan                                              45
# Kuwait                                                  45
# Sri Lanka                                               45
# Turks and Caicos Islands                                44
# West Bank and Gaza                                      44
# Bhutan                                                  42
# Fiji                                                    41
# Suriname                                                40
# Algeria                                                 39
# Egypt, Arab Rep.                                        39
# Tanzania                                                38
# Lebanon                                                 38
# Tajikistan                                              37
# British Virgin Islands                                  37
# Middle East & North Africa                              37
# South Asia                                              37
# Lower middle income                                     37
# Upper middle income                                     37
# Europe & Central Asia                                   37
# Latin America & Caribbean                               37
# Seychelles                                              37
# North America                                           36
# Cabo Verde                                              36
# High income                                             36
# Haiti                                                   36
# Oman                                                    36
# Argentina                                               35
# Turkmenistan                                            35
# Kenya                                                   34
# United Arab Emirates                                    33
# Bolivia                                                 33
# Malaysia                                                32
# Iraq                                                    30
# Peru                                                    30
# Andorra                                                 30
# Yemen, Rep.                                             29
# Afghanistan                                             28
# Pakistan                                                27
# American Samoa                                          27
# China                                                   26
# Brunei Darussalam                                       26
# Eswatini                                                26
# Nepal                                                   26
# Namibia                                                 26
# Greenland                                               25
# Ghana                                                   25
# Cameroon                                                24
# Burundi                                                 23
# Sao Tome and Principe                                   23
# Zimbabwe                                                23
# Maldives                                                22
# Curacao                                                 21
# Cambodia                                                20
# Syrian Arab Republic                                    19
# Bangladesh                                              19
# Burkina Faso                                            16
# Monaco                                                  16
# Zambia                                                  16
# Kiribati                                                16
# Indonesia                                               15
# Saudi Arabia                                            15
# Tunisia                                                 15
# Botswana                                                14
# Liberia                                                 14
# Rwanda                                                  13
# Guam                                                    13
# Lesotho                                                 13
# Low income                                              13
# Sub-Saharan Africa                                      13
# Malawi                                                  13
# East Asia & Pacific                                     13
# Solomon Islands                                         13
# Sierra Leone                                            13
# Papua New Guinea                                        12
# Central African Republic                                12
# Tuvalu                                                  12
# Timor-Leste                                             11
# Viet Nam                                                11
# Mozambique                                              11
# Guinea-Bissau                                           10
# Iran, Islamic Rep.                                      10
# Congo, Dem. Rep.                                         9
# Samoa                                                    9
# Cote d'Ivoire                                            8
# South Sudan                                              7
# St. Martin (French part)                                 6
# Isle of Man                                              6
# Somalia                                                  6
# Vanuatu                                                  6
# Mali                                                     5
# Sudan                                                    5
# Small states                                             4
# Low & middle income                                      4
# Middle income                                            4
# Least developed countries: UN classification             4
# Libya                                                    4
# Palau                                                    4
# Channel Islands                                          4
# French Polynesia                                         4
# Sub-Saharan Africa (IDA & IBRD countries)                4
# Angola                                                   4
# Other small states                                       4
# Pacific island small states                              4
# Heavily indebted poor countries (HIPC)                   4
# New Caledonia                                            4
# Mauritania                                               3
# South Asia (IDA & IBRD)                                  3
# Micronesia, Fed. Sts.                                    3
# Middle East & North Africa (IDA & IBRD countries)        3
# Marshall Islands                                         3
# OECD members                                             3
# Europe & Central Asia (IDA & IBRD countries)             3
# East Asia & Pacific (IDA & IBRD countries)               3
# Pre-demographic dividend                                 3
# Post-demographic dividend                                3
# Arab World                                               3
# Sub-Saharan Africa (excluding high income)               3
# Africa Western and Central                               3
# Africa Eastern and Southern                              3
# Latin America & the Caribbean (IDA & IBRD countries)     3
# Central Europe and the Baltics                           3
# Turkey                                                   3
# IDA total                                                3
# Fragile and conflict affected situations                 3
# European Union                                           3
# Euro area                                                3
# IBRD only                                                3
# Europe & Central Asia (excluding high income)            3
# Early-demographic dividend                               3
# East Asia & Pacific (excluding high income)              3
# Late-demographic dividend                                3
# IDA & IBRD total                                         3
# IDA blend                                                3
# Caribbean small states                                   3
# Latin America & Caribbean (excluding high income)        3
# Middle East & North Africa (excluding high income)       3
# IDA only                                                 3
# Nigeria                                                  2
# Niger                                                    2
# Gibraltar                                                2
# Sub-Saharan Africa (all income levels)                   1
# Middle East & North Africa (all income levels)           1
# Benin                                                    1
# Eritrea                                                  1
# Senegal                                                  1
# East Asia & Pacific (all income levels)                  1
# Ethiopia                                                 1
# Latin America & Caribbean (all income levels)            1
# Europe & Central Asia (all income levels)                1
# Arab League states                                       1
# Name: count, dtype: int64

# %%
data_WB.columns
# Out:
# Index(['series_id', 'country_code', 'country_name', 'year', 'value'], dtype='object')

# %%
type(data_WB)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### 2. Subsetting, wrangling, and cleaning time-series data

# %% [markdown]
# ##### 2.1 Data wrangling and subsetting

# %%
counts_2 =data_WB['year'].value_counts().sort_index()

# %%
print(counts_2)
# Out:
# year
# 1990    175
# 1991    163
# 1992    176
# 1993    181
# 1994    196
# 1995    198
# 1996    205
# 1997    202
# 1998    196
# 1999    215
# 2000    237
# 2001    257
# 2002    260
# 2003    278
# 2004    306
# 2005    312
# 2006    330
# 2007    348
# 2008    374
# 2009    397
# 2010    441
# 2011    430
# 2012    485
# 2013    402
# 2014    442
# 2015    449
# 2016    411
# 2017    421
# 2018    394
# 2019    406
# 2020    383
# 2021    318
# 2022      5
# 2023      7
# Name: count, dtype: int64

# %%
# subset of data from 2000 to 2020: this provides a balance bewteen recent trends and sufficient data points
subset = data_WB[(data_WB['year'] >= 2000) & (data_WB['year'] <= 2020)]

# %%
subset.head()
# Out:
#            series_id country_code country_name  year  value
# None
# 0     VC.PKP.TOTL.UN          XKX       Kosovo  2017  357.0
# 1     VC.PKP.TOTL.UN          XKX       Kosovo  2016  462.0
# 2     VC.PKP.TOTL.UN          XKX       Kosovo  2015  640.0
# 3     VC.PKP.TOTL.UN          XKX       Kosovo  2014  736.0
# 4     VC.PKP.TOTL.UN          XKX       Kosovo  2013  756.0

# %%
subset.shape
# Out:
# (7763, 5)

# %%
subset = subset.sort_values('year')

# %%
# Check for missing values

subset.isnull().sum()
# Out:
# series_id       0
# country_code    0
# country_name    0
# year            0
# value           0
# dtype: int64

# %%
# Check for duplicates

dups = subset.duplicated()
dups.sum()
# No dups
# Out:
# 0

# %%
subset.set_index('year', inplace=True)

# %%
plt.figure(figsize=(15,5), dpi=100)
plt.plot(subset.index, subset['value'])
plt.xlabel('Year')
plt.ylabel('Value')
plt.title('Global GDP Growth Over Time (2000 - 2020)')
plt.show()

# %%
import matplotlib.ticker as ticker

plt.gca().xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:.0f}"))

# %%
plt.figure(figsize=(15,5), dpi=100)
plt.plot(subset.index, subset['value'])
plt.xlabel('Year')
plt.ylabel('Value')
plt.title('Global GDP Growth Over Time (2000 - 2020)')
plt.gca().xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:.0f}"))
plt.show()

# %%
subset = subset.sort_values('year')

plt.figure(figsize=(15, 5))
plt.plot(subset.index, subset['value'], linewidth=2)

plt.gca().xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:.0f}"))

plt.xlabel('Year')
plt.ylabel('Value')
plt.title('Global GDP Growth Over Time (2000 - 2020)')
plt.grid(True)
plt.show()

# %%
# can only get it to appear as a column graph rather than line

# %% [markdown]
# #### 3. Time-series analysis:decomposition

# %%
# Extract the 'value' time series
ts = subset['value']

period = 12  

# Perform seasonal decomposition
decomposition = sm.tsa.seasonal_decompose(ts, model='additive', period=period)

from pylab import rcParams # This will define a fixed size for all special charts.

rcParams['figure.figsize'] = 18, 7

# Plot the decomposition
decomposition.plot()
plt.show()

# %% [markdown]
# The decomposition results reveal several key insights about the data. The original observed series shows a clear upward trend over time, indicating long-term growth, likely driven by economic or other cumulative factors. The trend component confirms this steady increase from around 2000 to 2020. Additionally, the seasonal component exhibits a consistent, repeating pattern within each year, suggesting regular cyclical fluctuations that could be influenced by seasonal factors, economic cycles, or policy changes occurring annually. The magnitude of these seasonal variations remains relatively stable throughout the period. The residual or irregular component appears to be scattered with no obvious pattern, representing random noise or other unforeseen influences not captured by the trend or seasonal components. Overall, the data demonstrates a strong long-term growth trend with predictable seasonal effects, while minor irregular fluctuations are due to unpredictable factors. This decomposition provides useful insights for understanding the underlying patterns in the dataset, which can aid in forecasting and decision-making.

# %% [markdown]
# #### 4. Testing for stationarity

# %%
from statsmodels.tsa.stattools import adfuller # Import the adfuller() function

# %%
# Define the function
def dickey_fuller(timeseries):
    print('Dickey-Fuller Stationarity test:')
    test = adfuller(timeseries, autolag='AIC')
    result = pd.Series(test[0:4], index=['Test Statistic', 'p-value', 'Number of Lags Used', 'Number of Observations Used'])
    for key, value in test[4].items():
        result['Critical Value (%s)' % key] = value
    print(result)

# Apply the function to your data
dickey_fuller(subset['value'])
# Out:
# Dickey-Fuller Stationarity test:
# Test Statistic                -1.169987e+01
# p-value                        1.578098e-21
# Number of Lags Used            3.500000e+01
# Number of Observations Used    7.727000e+03
# Critical Value (1%)           -3.431197e+00
# Critical Value (5%)           -2.861914e+00
# Critical Value (10%)          -2.566969e+00
# dtype: float64

# %%
# Check out a plot of autocorrelations

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
# Here, you import the autocorrelation and partial correlation plots

plot_acf(subset['value'])
plt.show()

# %% [markdown]
# The autocorrelation plot indicates that the data exhibits very little correlation between current values and past values beyond the immediate point. The first bar, at lag 0, is at 1, which is expected because it measures the correlation of the series with itself. However, subsequent bars are close to zero and fall within the confidence intervals, suggesting that there is no significant autocorrelation at these lags. This implies that the data points are relatively independent over time and do not follow strong cyclical or seasonal patterns. Such a pattern indicates the series may be largely random, with no predictable relationships based on past values. The lack of substantial autocorrelation suggests that simple models relying on lagged values may not effectively capture underlying patterns, and more complex or different modeling approaches might be needed for forecasting or further analysis. Overall, the data appears to be primarily driven by random fluctuations rather than by significant temporal dependencies.

# %% [markdown]
# #### 5. Stationarising the World Bank Data

# %%
# Convert 'value' to numeric, coercing errors to NaN
subset['value'] = pd.to_numeric(subset['value'], errors='coerce')

# drop NaN values if any appeared
subset = subset.dropna(subset=['value'])

# %%
data_diff = subset['value'] - subset['value'].shift(1)

# %%
data_diff = subset['value'].diff()

# %%
print(data_diff.head())
# Out:
# year
# 2000         NaN
# 2000   -0.660634
# 2000    5.759108
# 2000   -6.795952
# 2000   -0.822649
# Name: value, dtype: float64

# %%
# Drop NaN values from the differenced series

data_diff = data_diff.dropna()

# %%
print(data_diff.head())
# Out:
# year
# 2000    -0.660634
# 2000     5.759108
# 2000    -6.795952
# 2000    -0.822649
# 2000    13.201303
# Name: value, dtype: float64

# %%
# Check out what the differencing did to the time-series curve

plt.figure(figsize=(15,5), dpi=100)
plt.plot(data_diff)

# %%
dickey_fuller(data_diff)
# Out:
# Dickey-Fuller Stationarity test:
# Test Statistic                  -24.982716
# p-value                           0.000000
# Number of Lags Used              36.000000
# Number of Observations Used    7725.000000
# Critical Value (1%)              -3.431197
# Critical Value (5%)              -2.861914
# Critical Value (10%)             -2.566969
# dtype: float64

# %%
plot_acf(data_diff)
plt.show()
